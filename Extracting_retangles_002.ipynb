# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/marquesgabi/blob/master/Extracting_retangles_002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
#from skimage import data
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
#from skimage import io, util
#import mahotas.features.texture as mht
#import mahotas.features
#import os 
import zipfile
#from skimage import filters
#from skimage import exposure
#import skimage.feature as sk
#from google.colab import files
#from numpy import linalg as LA
#from scipy.signal import find_peaks
#from scipy.signal import peak_prominences
#from scipy.signal import peak_widths
#import re

#import Go2Mahotas
# %matplotlib inline

# %%
# !git clone https://github.com/ucfilho/marquesgabi #clonar do Github
# %cd marquesgabi
import Go2BlackWhite #this function is located in marquesgabi
# Out:
# Cloning into 'marquesgabi'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 374 (delta 16), reused 0 (delta 0), pack-reused 343
# Receiving objects: 100% (374/374), 8.51 MiB | 9.81 MiB/s, done.
# Resolving deltas: 100% (210/210), done.
# /content/marquesgabi

# %%
'''

'''
# Out:
# '\n\n'

# %%
#cv.drawContours(img, contours, -1, (0,255,0), 3)

# %%
Size=800 # tamanho da foto

# %%
# !wget http://ftp.feq.ufu.br/ubirajara/GrBuInd.zip
Transfere='GrBuInd.zip'
# Out:
# --2019-12-13 17:30:40--  http://ftp.feq.ufu.br/ubirajara/GrBuInd.zip
# Resolving ftp.feq.ufu.br (ftp.feq.ufu.br)... 200.19.144.11
# Connecting to ftp.feq.ufu.br (ftp.feq.ufu.br)|200.19.144.11|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 497627 (486K) [application/zip]
# Saving to: ‘GrBuInd.zip’
#
# GrBuInd.zip         100%[===================>] 485.96K   295KB/s    in 1.6s
#
# 2019-12-13 17:30:42 (295 KB/s) - ‘GrBuInd.zip’ saved [497627/497627]

# %%
file_name = zipfile.ZipFile(Transfere, 'r')
file_name.extractall()

# %%
ww,img_name=Go2BlackWhite.BlackWhite(Transfere,Size) # ww contain all photos in black and white
plt.axis("off")
plt.imshow(ww[0], cmap = "gray")

# %%
print(ww[0].shape)
# Out:
# (800, 800)

# %%
Num=100
Size=100
Foto=np.zeros((Size,Size))
for i in range(Size):
  for j in range(Size):
    Foto[i,j]=ww[0][i,j]
#Foto=Foto.havel()
plt.axis("off")
plt.imshow(Foto.reshape(Size,Size), cmap = "gray")
