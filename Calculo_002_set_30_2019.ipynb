# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/marquesgabi/blob/master/Calculo_002_set_30_2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# carrega as bibliotecas do python

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import os 
import cv2
import zipfile
from skimage import data
from skimage import filters
from skimage import exposure
import numpy as np
from google.colab import files

# %%
# a primeira vez q executar coloque Num=1
# carregar o arquivo de Sugar_set_30_2019.zip na primeira vez
# carregar o arquivo de Sugar_Sugar.zip demais vezes
Num=2

# %%
from google.colab import files
def getLocalFiles():
    _files = files.upload()
    if len(_files) >0:
       for k,v in _files.items():
         open(k,'wb').write(v)
getLocalFiles()
# Out:
#      <input type="file" id="files-53d5ecff-1316-49ef-8c14-31ef93b924e4" name="files[]" multiple disabled />
#      <output id="result-53d5ecff-1316-49ef-8c14-31ef93b924e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Sugar_set_30_2019.zip to Sugar_set_30_2019 (2).zip

# %%
if (Num==1):
  file_name = zipfile.ZipFile('Sugar_set_30_2019.zip', 'r')
  file_name.extractall()

# %%
if (Num==1):
  # all images are load in variable x...
  FILE='Sugar_set_30_2019.zip'
  img_name=[]
  x=[]

  with zipfile.ZipFile(FILE, "r") as f:
      for name in f.namelist():
          img_name.append(name)
          #x.append(cv2.cvtColor(cv2.imread(name), cv2.COLOR_BGR2RGB))
          #x.append(cv2.cvtColor(cv2.imread(name), cv2.COLOR_BGR2GRAY))
          x.append(cv2.cvtColor(cv2.imread(name), cv2.COLOR_RGB2GRAY))

# %%
plt.axis("off")
plt.imshow(x[0], cmap = "gray")

# %%
print(x[0])
# Out:
# [[ 95  81  78 ...  95  84 102]
#  [104  89  83 ...  92  82  96]
#  [101  91  86 ...  92  88  95]
#  ...
#  [103 100  98 ... 105 115 114]
#  [ 98  97  97 ...  99 112 110]
#  [ 97  96  96 ...  96 107 104]]
