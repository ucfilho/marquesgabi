# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/marquesgabi/blob/master/Mahotas_Fracionado_teste_002_nov_08_2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mahotas
# Out:
# Collecting mahotas
#   Downloading https://files.pythonhosted.org/packages/27/4b/72581c4316b2fb08cbcb3309d9f2eccd40f09f6af6117545e75f4015c505/mahotas-1.4.8.tar.gz (1.5MB)
#      |████████████████████████████████| 1.5MB 2.6MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from mahotas) (1.17.3)
# Building wheels for collected packages: mahotas
#   Building wheel for mahotas (setup.py) ... done
#   Created wheel for mahotas: filename=mahotas-1.4.8-cp36-cp36m-linux_x86_64.whl size=4263966 sha256=3724e4c6d7cd22abc782187f69be7e6b5129cce647fb3d6a52cd63661946df3d
#   Stored in directory: /root/.cache/pip/wheels/3e/8b/93/690deca49a46242df274db70dbef26c0a6fa86e378b677e1ab
# Successfully built mahotas
# Installing collected packages: mahotas
# Successfully installed mahotas-1.4.8

# %%
# proximas etapas que falta : dividir a foto em 10x10 e aplicar o mahotas em cada foto
# encontrar 
# GLCM?
# COLOCAR MAIS VARIAVEIS NAS FOTOS
# VER QUAIS PARAMETROS USAR PARA CALCULAR O PSD (particle size distribution)
# GERAR AS IMAGENS ARTIFICIAIS

# %%
import numpy as np
import cv2
from skimage import data
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
from skimage import io, util
import mahotas.features.texture as mht
import mahotas.features
import os 
import zipfile
from skimage import filters
from skimage import exposure
import skimage.feature as sk
from google.colab import files
from numpy import linalg as LA
# %matplotlib inline

# %%
# !wget http://ftp.feq.ufu.br/ubirajara/Sugar_set_30_2019.zip
#!ls -l trash_nov_22_2018.zip
# Out:
# --2019-11-11 16:08:05--  http://ftp.feq.ufu.br/ubirajara/Sugar_set_30_2019.zip
# Resolving ftp.feq.ufu.br (ftp.feq.ufu.br)... 200.19.144.11
# Connecting to ftp.feq.ufu.br (ftp.feq.ufu.br)|200.19.144.11|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19584173 (19M) [application/zip]
# Saving to: ‘Sugar_set_30_2019.zip’
#
# Sugar_set_30_2019.z 100%[===================>]  18.68M  4.14MB/s    in 4.8s
#
# 2019-11-11 16:08:13 (3.88 MB/s) - ‘Sugar_set_30_2019.zip’ saved [19584173/19584173]

# %%
# https://buildmedia.readthedocs.org/media/pdf/mahotas/latest/mahotas.pdf

# Why there are only 13 features implemented? (pag 42)
# Only the first 13 features are implemented. The last (14th) feature is 
# normally considered to be unstable, although it
# is not clear to me why this is. (See this unanswered question on Cross-validated).

# What mahotas.features.haralick return as answer?  (pag 58)
# mahotas.features.haralick returns features in 4 directions. 
# We just take the mean (sometimes you use the spread ptp() too).

# Who uses mahotas? (pag 62)
# In June 2016, there were 34 papers citing the mahotas paper

# %%
file_name = zipfile.ZipFile('Sugar_set_30_2019.zip', 'r')
file_name.extractall()

# %%
# all images are resized in variable x, are in gray in variable p and in variable w are dataframe
FILE='Sugar_set_30_2019.zip'
img_name=[]
x=[]
p=[]
w=[]
Size=64 # trocar por 64 qdo acabar a analise

with zipfile.ZipFile(FILE, "r") as f:
    for name in f.namelist():
        img_name.append(name)
        #x.append(cv2.imread(name))
        x.append(cv2.resize(cv2.imread(name),(Size,Size)))

nrow=len(img_name)
ncol=Size*Size
pp=np.zeros((nrow,ncol))
for i in range(nrow):
    w.append(cv2.cvtColor(np.array(x[i]), cv2.COLOR_BGR2GRAY))
    pp[i,:]=w[i].ravel()

# %%
Nomes=['ASM','constrast','correl','variance','inv diff mom','sum aveg',
       'sum var','sum entropy','entropy','dif var','dif entropy','IMC1',
       'IMC2']

# %%
Nfotos=len(img_name)
GLCM=[]
for k in range(Nfotos):
  p=pp[k,:].reshape(Size,Size)
  #MAT=Go2GLCM.GLCM(p)
  Mahotas =pd.DataFrame(mahotas.features.haralick(p.astype(int)), columns =Nomes)
  GLCM=[]
  for i in Nomes:
    GLCM.append(Mahotas[i].mean())
  glcm_haralick=pd.DataFrame(GLCM,index=Nomes,columns=['glcm'])
  pd.set_option('display.max_columns', 30)
  print(glcm_haralick)
  
  #GLCM.append(MAT.ravel())
# Out:
#                     glcm
# ASM             0.001476
# constrast     305.240098
# correl          0.199666
# variance      190.621719
# inv diff mom    0.115654
# sum aveg      229.094214
# sum var       457.246779
# sum entropy     5.766622
# entropy         9.884020
# dif var         0.000191
# dif entropy     4.602337
# IMC1           -0.073765
# IMC2            0.728477
#                     glcm
# ASM             0.001649
# constrast     287.752938
# correl          0.229284
# variance      186.590528
# inv diff mom    0.127302
# sum aveg      229.683062
# sum var       458.609176
# sum entropy     5.693573
# entropy         9.726509
# dif var         0.000210
# dif entropy     4.504156
# IMC1           -0.074611
# IMC2            0.727450
#                     glcm
# ASM             0.001641
# constrast     288.141489
# correl          0.216033
# variance      183.678006
# inv diff mom    0.121680
# sum aveg      229.022938
# sum var       446.570533
# sum entropy     5.687071
# entropy         9.719157
# dif var         0.000207
# dif entropy     4.500257
# IMC1           -0.071857
# IMC2            0.717719
#                     glcm
# ASM             0.001416
# constrast     318.477744
# correl          0.112644
# variance      179.396656
# inv diff mom    0.118230
# sum aveg      230.611534
# sum var       399.108880
# sum entropy     5.810023
# entropy         9.914302
# dif var         0.000193
# dif entropy     4.578683
# IMC1           -0.068763
# IMC2            0.711426
#                     glcm
# ASM             0.001545
# constrast     301.958875
# correl          0.129128
# variance      173.292477
# inv diff mom    0.123509
# sum aveg      217.663722
# sum var       391.211033
# sum entropy     5.751793
# entropy         9.798644
# dif var         0.000208
# dif entropy     4.502971
# IMC1           -0.067493
# IMC2            0.703658
#                     glcm
# ASM             0.001471
# constrast     296.965795
# correl          0.159959
# variance      176.703401
# inv diff mom    0.121148
# sum aveg      231.439264
# sum var       409.847810
# sum entropy     5.856384
# entropy         9.881145
# dif var         0.000203
# dif entropy     4.522949
# IMC1           -0.076853
# IMC2            0.738900
#                     glcm
# ASM             0.001442
# constrast     343.851927
# correl          0.096654
# variance      190.251434
# inv diff mom    0.117843
# sum aveg      231.248018
# sum var       417.153811
# sum entropy     5.815557
# entropy         9.919260
# dif var         0.000191
# dif entropy     4.604049
# IMC1           -0.070411
# IMC2            0.717533
#                     glcm
# ASM             0.001400
# constrast     300.225047
# correl          0.118803
# variance      170.298173
# inv diff mom    0.121846
# sum aveg      232.168212
# sum var       380.967644
# sum entropy     5.894199
# entropy         9.954842
# dif var         0.000202
# dif entropy     4.550800
# IMC1           -0.073977
# IMC2            0.730972
#                     glcm
# ASM             0.001155
# constrast     303.168985
# correl          0.125607
# variance      173.309682
# inv diff mom    0.108167
# sum aveg      249.712585
# sum var       390.069742
# sum entropy     6.026242
# entropy        10.191507
# dif var         0.000181
# dif entropy     4.667930
# IMC1           -0.080165
# IMC2            0.756914
#                     glcm
# ASM             0.001265
# constrast     210.378680
# correl          0.133152
# variance      121.340067
# inv diff mom    0.111339
# sum aveg      249.090855
# sum var       274.981586
# sum entropy     5.872284
# entropy        10.055936
# dif var         0.000191
# dif entropy     4.593414
# IMC1           -0.065550
# IMC2            0.702758
#                     glcm
# ASM             0.001342
# constrast     201.837350
# correl          0.185916
# variance      123.952080
# inv diff mom    0.120639
# sum aveg      251.882552
# sum var       293.970972
# sum entropy     5.863546
# entropy         9.946029
# dif var         0.000209
# dif entropy     4.470851
# IMC1           -0.066147
# IMC2            0.702219
#                     glcm
# ASM             0.001229
# constrast     225.549500
# correl          0.135925
# variance      130.507231
# inv diff mom    0.110891
# sum aveg      247.686271
# sum var       296.479423
# sum entropy     5.912445
# entropy        10.099791
# dif var         0.000192
# dif entropy     4.610963
# IMC1           -0.070054
# IMC2            0.720742
#                     glcm
# ASM             0.001375
# constrast     222.753565
# correl          0.095735
# variance      123.171558
# inv diff mom    0.115556
# sum aveg      250.732592
# sum var       269.932667
# sum entropy     5.788117
# entropy         9.968120
# dif var         0.000191
# dif entropy     4.573146
# IMC1           -0.059184
# IMC2            0.674873
#                     glcm
# ASM             0.001319
# constrast     209.358401
# correl          0.141533
# variance      121.940345
# inv diff mom    0.115605
# sum aveg      255.228801
# sum var       278.402979
# sum entropy     5.879191
# entropy        10.017570
# dif var         0.000198
# dif entropy     4.570979
# IMC1           -0.065840
# IMC2            0.703079
#                     glcm
# ASM             0.001310
# constrast     193.805830
# correl          0.152004
# variance      114.279647
# inv diff mom    0.113709
# sum aveg      260.438436
# sum var       263.312756
# sum entropy     5.855796
# entropy        10.012460
# dif var         0.000195
# dif entropy     4.542095
# IMC1           -0.062153
# IMC2            0.688275
#                     glcm
# ASM             0.001717
# constrast     212.787899
# correl          0.081694
# variance      115.845044
# inv diff mom    0.125412
# sum aveg      236.645839
# sum var       250.592277
# sum entropy     5.613144
# entropy         9.654996
# dif var         0.000214
# dif entropy     4.422679
# IMC1           -0.052817
# IMC2            0.638473
#                     glcm
# ASM             0.002070
# constrast     207.577521
# correl          0.054067
# variance      109.728281
# inv diff mom    0.141075
# sum aveg      226.024792
# sum var       231.335602
# sum entropy     5.470976
# entropy         9.382311
# dif var         0.000243
# dif entropy     4.268874
# IMC1           -0.052819
# IMC2            0.631531
#                     glcm
# ASM             0.001912
# constrast     217.884994
# correl          0.075832
# variance      117.872908
# inv diff mom    0.134683
# sum aveg      230.568676
# sum var       253.606639
# sum entropy     5.564607
# entropy         9.525435
# dif var         0.000231
# dif entropy     4.324447
# IMC1           -0.052430
# IMC2            0.633166
#                     glcm
# ASM             0.001464
# constrast     173.048516
# correl          0.119821
# variance       98.302331
# inv diff mom    0.118229
# sum aveg      246.735394
# sum var       220.160806
# sum entropy     5.724767
# entropy         9.857010
# dif var         0.000216
# dif entropy     4.489907
# IMC1           -0.055718
# IMC2            0.656958
#                     glcm
# ASM             0.001581
# constrast     138.903917
# correl          0.159531
# variance       82.631709
# inv diff mom    0.123219
# sum aveg      246.443248
# sum var       191.622918
# sum entropy     5.694382
# entropy         9.766537
# dif var         0.000224
# dif entropy     4.421329
# IMC1           -0.057326
# IMC2            0.661802
#                     glcm
# ASM             0.001556
# constrast     147.318947
# correl          0.125748
# variance       84.254178
# inv diff mom    0.120779
# sum aveg      247.785062
# sum var       189.697765
# sum entropy     5.673941
# entropy         9.790603
# dif var         0.000212
# dif entropy     4.460088
# IMC1           -0.054255
# IMC2            0.648594
#                     glcm
# ASM             0.001720
# constrast     103.772514
# correl          0.133624
# variance       59.889446
# inv diff mom    0.124677
# sum aveg      254.990353
# sum var       135.785268
# sum entropy     5.517092
# entropy         9.618557
# dif var         0.000222
# dif entropy     4.363424
# IMC1           -0.044998
# IMC2            0.598023
#                     glcm
# ASM             0.001548
# constrast     124.106457
# correl          0.160194
# variance       73.890907
# inv diff mom    0.120220
# sum aveg      259.806342
# sum var       171.457171
# sum entropy     5.661312
# entropy         9.802885
# dif var         0.000210
# dif entropy     4.446886
# IMC1           -0.049752
# IMC2            0.627250
#                     glcm
# ASM             0.001743
# constrast      96.114411
# correl          0.156740
# variance       56.989590
# inv diff mom    0.126398
# sum aveg      253.355841
# sum var       131.843949
# sum entropy     5.535133
# entropy         9.617017
# dif var         0.000264
# dif entropy     4.346024
# IMC1           -0.046291
# IMC2            0.604909
