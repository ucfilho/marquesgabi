# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/marquesgabi/blob/master/Sugar_06_maio_02_2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#%matplotlib inline
#from matplotlib import pyplot as plt
#from PIL import Image
#import numpy as np


# %matplotlib inline
from matplotlib import pyplot as plt
import os 
import cv2
import zipfile

# %%
# !wget http://ftp.feq.ufu.br/ubirajara/TesteSugarAbr25.zip
# Out:
# --2019-05-02 19:53:35--  http://ftp.feq.ufu.br/ubirajara/TesteSugarAbr25.zip
# Resolving ftp.feq.ufu.br (ftp.feq.ufu.br)... 200.19.144.11
# Connecting to ftp.feq.ufu.br (ftp.feq.ufu.br)|200.19.144.11|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 158733 (155K) [application/zip]
# Saving to: ‘TesteSugarAbr25.zip.6’
#
# TesteSugarAbr25.zip 100%[===================>] 155.01K   156KB/s    in 1.0s
#
# 2019-05-02 19:53:37 (156 KB/s) - ‘TesteSugarAbr25.zip.6’ saved [158733/158733]

# %%
file_name = zipfile.ZipFile('TesteSugarAbr25.zip', 'r')
file_name.extractall()

# %%
# all images are load in variable x...
FILE='TesteSugarAbr25.zip'
img_name=[]
x=[]
with zipfile.ZipFile(FILE, "r") as f:
    for name in f.namelist():
        img_name.append(name)
        x.append(cv2.cvtColor(cv2.imread(name), cv2.COLOR_BGR2RGB))

plt.axis("off")
plt.imshow(x[0])

# %%
resized_image = cv2.resize(x[0], (4,4))
for i in resized_image:
  print(i)
# Out:
# [[ 61  59  42]
#  [  0   0   0]
#  [  1   2   2]
#  [202 150  93]]
# [[ 29  25   2]
#  [214 204 169]
#  [222 217 194]
#  [ 68  43  10]]
# [[ 40  36  10]
#  [226 218 191]
#  [230 224 195]
#  [ 95  77  38]]
# [[ 57  50  10]
#  [167 157 122]
#  [230 228 212]
#  [ 71  44  27]]

# %%
Indice=x[0].shape
print(Indice)
print(x[0][0,0,0])
print(Indice[0])
# Out:
# (480, 640, 3)
# 214
# 480

# %%
N1=Indice[0]
N2=Indice[1]
N3=Indice[2]
Ref=200
for i in range(N1):
  for j in range(N2):
    for k in range(N3):
      if(x[0][i,j,k]>Ref):
        x[0][i,j,k]=0

# %%
plt.axis("off")
plt.imshow(x[0])

# %%
Indice=x[1].shape
N1=Indice[0]
N2=Indice[1]
N3=Indice[2]
Ref=500
for i in range(N1):
  for j in range(N2):
    for k in range(N3):
      if(sum(x[1][i,j,:])>Ref):
        x[1][i,j,k]=255
      else:
        x[1][i,j,k]=0

# %%
plt.axis("off")
plt.imshow(x[1])

# %%
a=x[0][0,0,:]
print(sum(a))
print(a)
# Out:
# 307
# [  0 171 136]

# %%
Indice=x[1].shape
N1=Indice[0]
N2=Indice[1]
N3=Indice[2]
Ref=250
for i in range(N1):
  for j in range(N2):
    for k in range(N3):
      if(x[1][i,j,k]>Ref):
        x[1][i,j,k]=0
      else:
        x[1][i,j,k]=255

# %%
plt.axis("off")
plt.imshow(x[1])

# %%
"""
# !wget http://ftp.feq.ufu.br/ubirajara/preto.png
# !ls
Nova=[]
Nova.append(cv2.cvtColor(cv2.imread("preto.png"), cv2.COLOR_BGR2RGB)) 
plt.axis("off")
plt.imshow(Nova)
"""
for i in range(N1):
  for j in range(N2):
    for k in range(N3):
        x[1][i,j,k]=0
plt.axis("off")
plt.imshow(x[1])

# %%
# !ls
# Out:
# Q1-1-1.jpg  sample_data		   TesteSugarAbr25.zip.2  TesteSugarAbr25.zip.5
# Q1-1-2.jpg  TesteSugarAbr25.zip    TesteSugarAbr25.zip.3  TesteSugarAbr25.zip.6
# Q1-1-3.jpg  TesteSugarAbr25.zip.1  TesteSugarAbr25.zip.4
