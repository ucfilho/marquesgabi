# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/marquesgabi/blob/master/Extracting_retangles_004.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
from random import randint
import zipfile
# %matplotlib inline

# %%
# !git clone https://github.com/ucfilho/marquesgabi #clonar do Github
# %cd marquesgabi
import Go2BlackWhite #this function is located in marquesgabi
# Out:
# fatal: destination path 'marquesgabi' already exists and is not an empty directory.
# /content/marquesgabi

# %%
Size=1000 # tamanho da foto

# %%
# !wget http://ftp.feq.ufu.br/ubirajara/GrBuInd.zip
Transfere='GrBuInd.zip'
# Out:
# --2019-12-13 18:24:26--  http://ftp.feq.ufu.br/ubirajara/GrBuInd.zip
# Resolving ftp.feq.ufu.br (ftp.feq.ufu.br)... 200.19.144.11
# Connecting to ftp.feq.ufu.br (ftp.feq.ufu.br)|200.19.144.11|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 497627 (486K) [application/zip]
# Saving to: ‘GrBuInd.zip.12’
#
# GrBuInd.zip.12      100%[===================>] 485.96K   288KB/s    in 1.7s
#
# 2019-12-13 18:24:28 (288 KB/s) - ‘GrBuInd.zip.12’ saved [497627/497627]

# %%
file_name = zipfile.ZipFile(Transfere, 'r')
file_name.extractall()

# %%
ww,img_name=Go2BlackWhite.BlackWhite(Transfere,Size) # ww contain all photos in black and white
plt.axis("off")
plt.imshow(ww[0], cmap = "gray")

# %%
print(ww[0].shape)
# Out:
# (1000, 1000)

# %%
Num=100
NSize=100
Foto=np.zeros((NSize,NSize))
for i in range(NSize):
  for j in range(NSize):
    Foto[i,j]=ww[0][i,j]

plt.axis("off")
plt.imshow(Foto, cmap = "gray")

# %%
Grain=200
NSize=100
Nx=int(Size*np.random.random())
Ny=int(Size*np.random.random())
Wx=Grain+Nx
Wy=Grain+Ny
if(Wx>Size):
  Nx=Size-Grain
if(Wy>Size):
  Ny=Size-Grain  
Foto=np.zeros((NSize,NSize))
for i in range(NSize):
  for j in range(NSize):
    Foto[i,j]=ww[0][i+Nx,j+Ny]

plt.axis("off")
plt.imshow(Foto, cmap = "gray")

# %%
Ntest=20
MaxGrain=Size/10
MaxSize=Size/10
MinGrain=Size/20
MinSize=Size/20
for k in range(Ntest):
  Grain=MinGrain+(MaxGrain-MinGrain)*np.random.random()
  Grain=int(Grain)
  NSize=MinSize+(MaxSize-MinSize)*np.random.random()
  NSize=int(NSize)
  NomeFig='Fig '+str((k+1))+' size= '+str(NSize)
  Nx=int(Size*np.random.random())
  Ny=int(Size*np.random.random())
  Wx=NSize+Nx
  Wy=NSize+Ny
  if(Wx>Size):
    Nx=Size-NSize
  if(Wy>Size):
    Ny=Size-NSize 
  Foto=np.zeros((NSize,NSize))
  for i in range(NSize):
    for j in range(NSize):
      Foto[i,j]=ww[0][i+Nx,j+Ny]
  fig =plt.figure(k+1)
  fig.suptitle(NomeFig)
  plt.axis("off")
  plt.imshow(Foto, cmap = "gray")
